# %%
import openai
import os
openai.api_key = "<Enter your APIs>"
# Sample corporate policy data that the public model was never trained on
company_policy_context = """
Policy ID: SEC-2026-X. Employees traveling internationally are allowed a maximum 
stipend of $75 per day for meals. Receipts are strictly required for any individual 
expense exceeding $25. Alcohol expenses are completely non-reimbursable.
"""

# %%
def demonstrate_hallucination():
    print("=== SIMULATING UNGROUNDED ASSISTANT (High Risk of Hallucination) ===")
    
    # We ask a question about our specific policy WITHOUT giving the model the data
    prompt = "What is the company policy for buying a bottle of wine during an international work trip?"
    
    # Running with higher temperature to show how it creates an answer
    response = openai.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7 
    )
    print(f"User Asked: {prompt}")
    print(f"AI Response:\n{response.choices[0].message.content}\n")

# %%
def demonstrate_grounding():
    print("=== SIMULATING GROUNDED ASSISTANT (Strictly Anchored) ===")
    
    user_question = "What is the company policy for buying a bottle of wine during an international work trip?"
    
    # 1. Give strict behavioral boundaries
    system_instruction = "You are a factual compliance checker. Answer the user question using ONLY the provided context. If the context does not explicitly allow it, state that it is not permitted."
    
    # 2. Glue the private context and the user's question together
    full_prompt = f"Context:\n{company_policy_context}\n\nQuestion: {user_question}"
    
    # Running with temperature 0 for maximum factual consistency
    response = openai.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": system_instruction},
            {"role": "user", "content": full_prompt}
        ],
        temperature=0.0 
    )
    print(f"User Asked: {user_question}")
    print(f"AI Response:\n{response.choices[0].message.content}\n")

# %%
# Run both to let the class see the contrast
demonstrate_hallucination()
print("-" * 60)
demonstrate_grounding()
# Out:
# === SIMULATING UNGROUNDED ASSISTANT (High Risk of Hallucination) ===
# User Asked: What is the company policy for buying a bottle of wine during an international work trip?
# AI Response:
# Company policies regarding purchasing alcohol, including a bottle of wine during an international work trip, can vary significantly between organizations. However, here are some common elements you might find in such policies:
#
# 1. **Expense Reimbursement**: Many companies allow employees to expense reasonable costs for alcohol when entertaining clients or during business dinners. However, there may be limits on the amount or specific guidelines on when and how it can be purchased.
#
# 2. **Personal vs. Business Use**: If the wine is for personal consumption rather than for a business-related purpose, it may not be reimbursable. Employees should clarify whether the purchase is for business entertainment or for personal enjoyment.
#
# 3. **Local Laws and Customs**: Employees should be aware of local laws regarding alcohol consumption and purchases in the country they are visiting, as well as any cultural norms that may influence their decision to buy alcohol.
#
# 4. **Documentation**: Many companies require receipts for all expenses. Employees may need to provide a receipt along with a brief explanation of the business purpose of the purchase.
#
# 5. **Approval Process**: Some organizations might require prior approval from a manager or supervisor for purchasing alcohol, especially if it exceeds a certain amount.
#
# To ensure compliance, it's best to review your company's employee handbook or consult with your HR department for specific guidelines related to alcohol purchases during international work trips.
#
# ------------------------------------------------------------
# === SIMULATING GROUNDED ASSISTANT (Strictly Anchored) ===
# User Asked: What is the company policy for buying a bottle of wine during an international work trip?
# AI Response:
# The company policy states that alcohol expenses are completely non-reimbursable. Therefore, buying a bottle of wine during an international work trip is not permitted for reimbursement.
